# %% [markdown]
# ### **Question**
# ---

# %% [markdown]
# > 学长好，我现在想转行做数据分析，然后我学了tableau，PowerBI，> MySQL，python基础（正在学，）看了一本精益数据分析，关于业务相关> 的比如指标体系和分析框架网上找了一些资料还没看。
#
# > AB测试和机器学习方面的感觉太多内容了，特别是数学基础都快忘光了。> 我现在好焦虑，特别是今年行情不好，数分又太卷，网上刷刷知乎啥的越> 来越焦虑。
#
# > 但是我确实不喜欢现在的传统行业工作了，所以决定还是坚持下去，把> python练熟，sql就差刷题了，然后辅以一些业务相关的资料进行学习。
#
# > 就是想跟学长和大家倾诉一下，然后随便帮我看看这条路线可行吗。
#
# > 我今年26，普通本科，环工行业干了3年，但是一直都挺关注互联网相关的> 一些信息。以前有学前端，学了html,css，Js，然后又学了UI设计，准备> 给自己设计一个网站，但是缺乏系统性的学习和项目练手。后来玩黑暗之> 魂去了就给搁置了。
#
#
# > 这次因为公司有一大堆项目运行数据丢给我，说要我给处理处理。刚开始> 有点懵，后来网上看了tableau教程给他弄了个dashboard，出了个简单的> 分析报告。过程中发现数据分析远没有这么简单，然后就顺着思路学习> sql，python到现在了。
#
# > 这次真不想半途而废了。

# %% [markdown]
# ### **Answer**
# ---

# %% [markdown]
# **Johngo学长：很早就收到你的提问了，抱歉今天才有空回答**
#
# **1、大数据基础，用不着很深，因为我看到你有编程的一点基础**
# > hadoop生态的HDFS、hive要熟悉和使用，这对于你来说我估计不会很难，就是一些基础的原理+hiveSQL
# 现在数据分析的平台，尤其是中大型公司，甚至小公司已经布局了大数据平台，数据都存在于大数据平台，而以上说的 hive 是数据分析人员最为重要的取数手段！
#
# SQL 练习，牛客有sql练习的板块，可以使用（SQL基础操作，包括分组、聚合、表关联join、各种基本函数、开窗函数）
#
# **2、其次就是 python 的熟练掌握**
# > 以三大数据科学计算库为主（numpy、pandas、matplotlib，前两种最为重要）
# 学习方法可以使用《利用Python进行数据分析》（链接:百度网盘 请输入提取码 提取码:07r2）
# 可以结合我早之前找到的一个视频教程，可以参考：
# 以《利用Python进行数据分析》为教材的视频：链接:百度网盘 请输入提取码 提取码:gvt7 （分享了好多次，都失败，因此会加密+压缩，如果有解压密码：johngo_tec）
#
# 为什么有了大数据平台，sql计算还需要python？通常来说 HiveSQL 大多用来取数+简单计算，而真正的数据分析手段，必须要是Python来操作。
# 所以形成了一个基本的方式：hive取数，将结果用Python来计算（只是说通常这么做）
#
# **3、可视化**
# > 我看到你学习和使用了 tableau，PowerBI，尤其是 tableau 是业界首屈一指的可视化分析平台
# 但我目前不建议将大量精力投入到 Python 的可视化学习中。另外，可以多学习和使用 tableau 供自己使用，各大厂使用的可视化平台都不同，平常学习和使用一项即可。 虽然 tableau 目前在业界使用的也不是很多，尤其是国内。在业内，大公司都是自研可视化平台，中小型公司都是使用开源免费的分析平台。
#
# 所以，**tableau 可以使用和学习，在未来面试中可以有很大的帮助**。如果有精力，可以了解下国内的商业可视化bdp以及开源的superset 和 metabase（后两种需要自己搭建，看过你有前端的基础，应该不会很难）
#
# **_以上 3 点，是数据分析人员的核心必备能力！_**
#
# > 简单来说，sql取数，Python分析、最后可视化展现！
# 最重要的是：数据分析的思维要有意识的锻炼（也可以从《利用Python进行数据分析》寻找灵感）

# %% [markdown]
# ### **Answer_2**
# ---

# %% [markdown]
# > 我这里提到的大数据，主要是目前业界的数据基本都是存在于大数据平 台，而从大数据平台取数最直接最简单的方式就是 hive 工具（目前主要 的取数工具可能是**presto、spark、impala**等等，内存计算，速度快）
#
# > 为什么我还是让你学习 hive 呢，hive 数据计算的基石，其他任何的工> 具与hive类似，都是使用sql去实现。所以，重点还在hive！
#
#  这么说吧，**_精力投入 => Hive相关:python分析:可视化 = 4:5:1_**
#
# > 可能可视化的占比有点少了，可以适当增多一些
#
# > Hive相关，主要是sql的学习，因为sql通过hive取数，sql基本的学习内> 容都提到过了，还有一项重点，是以后面试必然会问到的，那就是「**hive> 优化**」，这个网上相关内容很多
#
# > 关于机器学习的话，我感觉会是一个很费力的一块内容。所以，用到的时> 候再学习吧，除了顶级数据分析师，机器学习的使用几率不会很多，而且> 如果想要使用，现在业界大厂成熟的工具很好用了。因此，没有必要投入> 太多的精力。
#
# 综上，重点还是 **「Hive相关:python分析:可视化 = 4:5:1」**，其中的 1 > 可能需要稍微再多一点点
